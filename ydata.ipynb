# %%
import pandas as pd
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv('data/savant_data_11.csv')
df.dropna(axis=1, how='all', inplace=True)
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            FF  2022-10-01           97.4          -1.43           6.25
# 1            SL  2022-10-01           85.5          -3.04           5.82
# 2            SL  2022-10-01           84.6          -3.24           5.65
# 3            SI  2022-10-01           93.0          -2.47           6.09
# 4            SI  2022-10-01           95.6          -1.75           5.64
# ...         ...         ...            ...            ...            ...
# 1158         FF  2022-10-01           96.3          -3.21           5.23
# 1159         SI  2022-10-01           96.4          -1.86           5.30
# 1160         SI  2022-10-01           97.1           2.86           5.59
# 1161         FC  2022-10-01           87.0          -2.56           5.87
# 1162         FF  2022-10-01           95.8          -1.25           6.26
#
#             player_name  batter  pitcher     events      description  ...  \
# ...

# %%
ProfileReport(df, title="Profiling Report")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
